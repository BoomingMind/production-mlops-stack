# %%
import boto3
import json
import os
from dotenv import load_dotenv

# --- Load environment variables (if using .env file) ---
load_dotenv()

# AWS credentials from environment variables
aws_access_key = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
aws_region = os.getenv("AWS_DEFAULT_REGION")  # default region if not specified

# --- Configuration ---
bucket_name = "my-feature-store-data"
file_key = "raw-data/historical_aqi_weather_data.json"  # e.g. "data/sample.json"

# --- Initialize S3 client ---
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key,
    region_name=aws_region
)

# --- Read JSON file from S3 ---
response = s3.get_object(Bucket=bucket_name, Key=file_key)
content = response["Body"].read().decode("utf-8")

# Parse JSON
data = json.loads(content)

# --- Print / Use Data ---
print("JSON data loaded successfully!")
print(json.dumps(data, indent=2))
# Out:
# JSON data loaded successfully!
# [
#   {
#     "aqi": {
#       "coord": {
#         "lon": 67.0207,
#         "lat": 24.8547
#       },
#       "list": [
#         {
#           "main": {
#             "aqi": 4
#           },
#           "components": {
#             "co": 1201.63,
#             "no": 0.01,
#             "no2": 45.24,
#             "o3": 41.13,
#             "so2": 8.82,
#             "pm2_5": 68.43,
#             "pm10": 112.67,
#             "nh3": 11.78
#           },
#           "dt": 1729623600
#         }
#       ]
#     },
#     "weather": {
#       "temperature_2m": 27.3,
#       "relative_humidity_2m": 81,
#       "precipitation": 0.0,
#       "wind_speed_10m": 11.7,
#       "wind_direction_10m": 314,
#       "surface_pressure": 1011.3,
#       "cloudcover": 0,
#       "visibility": null,
#       "dew_point_2m": 23.8,
#       "apparent_temperature": 31.5,
#       "shortwave_radiation": 0.0,
#       "et0_fao_evapotranspiration": 0.03,
# ...

# %%
from dotenv import load_dotenv
import os

load_dotenv()

aws_access_key = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")

# %%
# aws_region = os.getenv("AWS_DEFAULT_REGION")

print(aws_access_key, aws_region)
# Out:
# AKIA5SCPHA2BGOSECNFK eu-north-1

# %%
import pandas as pd

# %%
bucket_name = 'my-feature-store-data'
data_key = 'raw-data/aqi_weather_data.csv'
        # Create S3 client
s3 = boto3.client(
    's3',
    aws_access_key_id=os.getenv('AWS_ACCESS_KEY_ID'),
    aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'),
)
# Download the file from S31
s3.download_file(bucket_name, data_key, 'aqi_weather_data.csv')
# Read the CSV file into a DataFrame
df = pd.read_csv('aqi_weather_data.csv')

# %%
df.tail()
# Out:
#       aqi_index      co    no   no2      o3   so2  pm2_5    pm10   nh3  \
# 4774        3.0   90.40  0.00  0.06   44.68  0.29  12.55   64.77  0.01
# 4775        3.0   89.68  0.00  0.07   44.05  0.30  13.12   65.45  0.01
# 4776        4.0  237.68  0.00  2.03   99.69  1.69  43.95  106.48  0.65
# 4777        4.0  237.68  0.00  2.03   99.69  1.69  43.95  106.48  0.65
# 4778        4.0  421.02  0.25  4.78  100.71  8.70  70.64  168.08  2.78
#
#       temperature_2m  ...  surface_pressure  dew_point_2m  \
# 4774            29.1  ...             997.6          25.5
# 4775            28.7  ...             997.6          25.7
# 4776            25.5  ...            1011.2          19.2
# 4777            25.5  ...            1011.2          19.1
# 4778            27.8  ...            1013.4          17.0
#
#       apparent_temperature  shortwave_radiation  et0_fao_evapotranspiration  \
# 4774                  34.2                  0.0                        0.04
# ...

# %%
len(df.columns)
# Out:
# 24

# %%
df.columns
# Out:
# Index(['aqi_index', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3',
#        'temperature_2m', 'relative_humidity_2m', 'precipitation',
#        'wind_speed_10m', 'wind_direction_10m', 'surface_pressure',
#        'dew_point_2m', 'apparent_temperature', 'shortwave_radiation',
#        'et0_fao_evapotranspiration', 'year', 'month', 'day', 'hour',
#        'cloudcover'],
#       dtype='object')
